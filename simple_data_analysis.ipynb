# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Here we have installed the required packages here...

# %%
from seaborn.utils import load_dataset
df=load_dataset('planets')
df.sample(10)
# Out:
#               method  number  orbital_period     mass  distance  year
# 849          Transit       4        6.164860      NaN       NaN  2014
# 752          Transit       2       18.648953      NaN       NaN  2012
# 199  Radial Velocity       2     6005.000000  5.30000     25.64  2012
# 472  Radial Velocity       1      464.300000  2.00000    106.38  2009
# 475  Radial Velocity       3      106.720000  0.03000     14.56  2011
# 711          Transit       5        2.896000      NaN    303.00  2012
# 231  Radial Velocity       6       16.356700  0.03800     39.39  2010
# 133  Radial Velocity       6       62.240000  0.00800      6.80  2013
# 263  Radial Velocity       3       40.114000  0.00755      6.06  2011
# 756          Transit       2       27.948145      NaN       NaN  2012

# %% [markdown]
# Here we took a sample of our dataset

# %%
df.shape
# Out:
# (1035, 6)

# %% [markdown]
# ti Gives the dimensions of the datafram

# %%
df.columns
# Out:
# Index(['method', 'number', 'orbital_period', 'mass', 'distance', 'year'], dtype='object')

# %%
df.dtypes
# Out:
# method             object
# number              int64
# orbital_period    float64
# mass              float64
# distance          float64
# year                int64
# dtype: object

# %% [markdown]
# this gives the data tyoes of the datafram

# %%
df.isnull()
# Out:
#       method  number  orbital_period   mass  distance   year
# 0      False   False           False  False     False  False
# 1      False   False           False  False     False  False
# 2      False   False           False  False     False  False
# 3      False   False           False  False     False  False
# 4      False   False           False  False     False  False
# ...      ...     ...             ...    ...       ...    ...
# 1030   False   False           False  False     False  False
# 1031   False   False           False  False     False  False
# 1032   False   False           False  False     False  False
# 1033   False   False           False  False     False  False
# 1034   False   False           False  False     False  False
#
# [1035 rows x 6 columns]
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# ...

# %% [markdown]
# This checks the null value

# %%
df.isnull().any()
# Out:
# method            False
# number            False
# orbital_period     True
# mass               True
# distance           True
# year              False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1030    False
# 1031    False
# 1032    False
# 1033    False
# 1034    False
# Length: 1035, dtype: bool

# %% [markdown]
# Checks for the duplicate data

# %%
df.duplicated().sample(20)
# Out:
# 1012    False
# 602     False
# 294     False
# 940     False
# 448     False
# 876     False
# 353     False
# 568     False
# 511     False
# 775     False
# 49      False
# 104     False
# 763     False
# 697     False
# 494     False
# 205     False
# 888     False
# 376     False
# 260     False
# 323     False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 4

# %%
df.describe()
# Out:
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# 50%       1.000000       39.979500    1.260000    55.250000  2010.000000
# 75%       2.000000      526.005000    3.040000   178.500000  2012.000000
# max       7.000000   730000.000000   25.000000  8500.000000  2014.000000

# %% [markdown]
# this give us basic statics of the dataset

# %%
df.skew()
# Out:
# <ipython-input-37-9e0b1e29546f>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# number             2.030572
# orbital_period    24.273067
# mass               2.550824
# distance           7.362539
# year              -1.326370
# dtype: float64

# %% [markdown]
# This will give us the skewness of the dataset which will help us to determine the basied coloumns

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['mass'],bins=100)
plt.show()

# %% [markdown]
# This gives us the mass of the planets according to the methods

# %%
df['mass'].fillna(2.638,inplace=True)

# %% [markdown]
# This helps in replaceing null values with the required values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            1035 non-null   float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
df['method'].value_counts()
# Out:
# Radial Velocity                  553
# Transit                          397
# Imaging                           38
# Microlensing                      23
# Eclipse Timing Variations          9
# Pulsar Timing                      5
# Transit Timing Variations          4
# Orbital Brightness Modulation      3
# Astrometry                         2
# Pulsation Timing Variations        1
# Name: method, dtype: int64

# %% [markdown]
# This gives us the number of times the method is performed

# %%
plt.figure(figsize=(10,7))
plt.pie(x=df['method'].value_counts().values,
        labels=df['method'].value_counts().index,
        autopct='%f')
plt.show()

# %% [markdown]
# This chat gives the ratio of the methodes

# %% [markdown]
# So,overall we get to clean the mass coloumn,find the skewness of the data and we found the most used testing methodes
